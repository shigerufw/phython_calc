# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def function_integral(x):
    a = (39/2)
    b = -111/2
    c = 35/111
    d = 1/2
    return d*np.tanh(a*x + b*np.arctan(c*x))

# %%
x_0 = np.linspace(-3,3,100)

# %%
y_integral = list(map(function_test,x_0))

# %%
plt.plot(x_0,y_integral)

# %%
np.pi
# Out:
# 3.141592653589793

# %%
def error_function(x):
    a = (39/2)
    b = -111/2
    c = 35/111
    d = 1/2
    return np.tanh(a*x/np.sqrt(np.pi) + b*np.arctan(c*x/np.sqrt(np.pi)))

# %%
y_error_fx = list(map(function_error, x_0))

# %%
plt.plot(x_0, y_error_fx)

# %%
plt.plot(x_0, (np.array(y_integral)-np.array(y_error_fx)))

# %% [markdown]
#     Aproximation form from the integral of a normal distribution function, read this paper for more information
#     https://www.hindawi.com/journals/mpe/2012/124029/

# %%
def error_function(x):
        a = (39/2)
        b = -111/2
        c = 35/111
        d = 1/2
        return np.tanh(a*x/np.sqrt(np.pi) + b*np.arctan(c*x/np.sqrt(np.pi)))

# %%
def fun_cummulative (x):
    
    return (1/2)*(1+error_function(x/np.sqrt(2)))

# %%
def probabilities (a,b):
    if a<b:
        return fun_cummulative(b)-fun_cummulative(a)
    else:
        return fun_cummulative(a)- fun_cummulative(b)

# %%
probabilities(1,-1)
# Out:
# 0.6828119747021708

# %%
y_cummulative = list(map(fun_cummulative,x_0))

# %%
plt.plot(x_0, y_cummulative)

# %% [markdown]
# ### 1 desv pad

# %%
fun_cummulative(1)-fun_cummulative(-1)
# Out:
# 0.6828119747021708

# %% [markdown]
# ### 2 desv pad

# %%
fun_cummulative(2)-fun_cummulative(-2)
# Out:
# 0.954461820784152

# %% [markdown]
# ### 3 desv pad

# %%
fun_cummulative(3)- fun_cummulative(-3)
# Out:
# 0.9973406350377756
